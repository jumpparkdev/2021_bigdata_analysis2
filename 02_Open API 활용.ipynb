# %% [markdown]
# # 2. Open API 활용
#
# ### 공공데이터포털 사이트 이용
# 1. 공공데이터포털 사이트 회원가입/로그인
# 2. 데이터 검색
# 3. API 사용 요청, 키 발급
# 4. API 메뉴얼 확인
# 5. API 연동 개발 및 테스트

# %%
import requests
import pandas as pd
import xmltodict
import json

# %% [markdown]
# ### 보건복지부 - 코로나19 감염현황 조회 서비스 (XML)

# %%
serviceKey = 'b9hGTJEotm7onQH20kHWpVbTbjOKOGAT8HYoLBOmXxGiN6uA2nrA8bpRss783vibuZoxkk51WJmsz83K3pVLkA%3D%3D'

url = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson?serviceKey={}&pageNo=1&numOfRows=10&startCreateDt=20200801&endCreateDt=20210830'.format(serviceKey)
url
# Out:
# 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson?serviceKey=b9hGTJEotm7onQH20kHWpVbTbjOKOGAT8HYoLBOmXxGiN6uA2nrA8bpRss783vibuZoxkk51WJmsz83K3pVLkA%3D%3D&pageNo=1&numOfRows=10&startCreateDt=20200801&endCreateDt=20210830'

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><accDefRate>2.0357530301</accDefRate><accExamCnt>13049682</accExamCnt><accExamCompCnt>12282875</accExamCompCnt><careCnt>27407</careCnt><clearCnt>220358</clearCnt><createDt>2021-08-30 09:40:07.28</createDt><deathCnt>2284</deathCnt><decideCnt>250049</decideCnt><examCnt>766807</examCnt><resutlNegCnt>12032826</resutlNegCnt><seq>619</seq><stateDt>20210830</stateDt><stateTime>00:00</stateTime><updateDt>2021-08-31 10:42:19.61</updateDt></item><item><accDefRate>2.0285186242</accDefRate><accExamCnt>13015920</accExamCnt><accExamCompCnt>12253326</accExamCompCnt><careCnt>27556</careCnt><clearCnt>218726</clearCnt><createDt>2021-08-29 09:30:47.611</createDt><deathCnt>2279</deathCnt><decideCnt>248561</decideCnt><examCnt>762594</examCnt><resutlNegCnt>12004765</resutlNegCnt><seq>618</seq><stateDt>20210829</stateDt><stateTime>00:00</stat
# ...

# %%
temp = xmltodict.parse(res.text)
temp
# Out:
# OrderedDict([('response',
#               OrderedDict([('header',
#                             OrderedDict([('resultCode', '00'),
#                                          ('resultMsg', 'NORMAL SERVICE.')])),
#                            ('body',
#                             OrderedDict([('items',
#                                           OrderedDict([('item',
#                                                         [OrderedDict([('accDefRate',
#                                                                        '2.0357530301'),
#                                                                       ('accExamCnt',
#                                                                        '13049682'),
#                                                                       ('accExamCompCnt',
#                                                                        '12282875'),
#                                                                       ('careCnt',
# ...

# %%
result = json.loads(json.dumps(temp))  # OrderedDict -> dict(type:str) -> dict
result
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'accDefRate': '2.0357530301',
#       'accExamCnt': '13049682',
#       'accExamCompCnt': '12282875',
#       'careCnt': '27407',
#       'clearCnt': '220358',
#       'createDt': '2021-08-30 09:40:07.28',
#       'deathCnt': '2284',
#       'decideCnt': '250049',
#       'examCnt': '766807',
#       'resutlNegCnt': '12032826',
#       'seq': '619',
#       'stateDt': '20210830',
#       'stateTime': '00:00',
#       'updateDt': '2021-08-31 10:42:19.61'},
#      {'accDefRate': '2.0285186242',
#       'accExamCnt': '13015920',
#       'accExamCompCnt': '12253326',
#       'careCnt': '27556',
#       'clearCnt': '218726',
#       'createDt': '2021-08-29 09:30:47.611',
#       'deathCnt': '2279',
#       'decideCnt': '248561',
#       'examCnt': '762594',
#       'resutlNegCnt': '12004765',
#       'seq': '618',
#       'stateDt': '20210829',
#       'stateTime': '00:00',
# ...

# %%
items = result['response']['body']['items']['item']

for item in items:
    print(item)
# Out:
# {'accDefRate': '2.0357530301', 'accExamCnt': '13049682', 'accExamCompCnt': '12282875', 'careCnt': '27407', 'clearCnt': '220358', 'createDt': '2021-08-30 09:40:07.28', 'deathCnt': '2284', 'decideCnt': '250049', 'examCnt': '766807', 'resutlNegCnt': '12032826', 'seq': '619', 'stateDt': '20210830', 'stateTime': '00:00', 'updateDt': '2021-08-31 10:42:19.61'}
# {'accDefRate': '2.0285186242', 'accExamCnt': '13015920', 'accExamCompCnt': '12253326', 'careCnt': '27556', 'clearCnt': '218726', 'createDt': '2021-08-29 09:30:47.611', 'deathCnt': '2279', 'decideCnt': '248561', 'examCnt': '762594', 'resutlNegCnt': '12004765', 'seq': '618', 'stateDt': '20210829', 'stateTime': '00:00', 'updateDt': '2021-08-31 10:42:09.632'}
# ...

# %%
# 일자(STATE_DT), 확진자수(DECIDE_CNT), 사망자수(DEATH_CNT), 치료중환자수(CARE_CNT)
state_dt = []
decide_cnt = []
death_cnt = []
care_cnt = []
for item in items:
    state_dt.append(item['stateDt'])
    decide_cnt.append(item['decideCnt'])
    death_cnt.append(item['deathCnt'])
    care_cnt.append(item['careCnt'])
    
state_dt
# Out:
# ['20210830',
#  '20210829',
#  '20210828',
#  '20210827',
#  '20210826',
#  '20210825',
#  '20210824',
#  '20210823',
#  '20210822',
#  '20210821',
#  '20210820',
#  '20210819',
#  '20210818',
#  '20210817',
#  '20210816',
#  '20210815',
#  '20210814',
#  '20210813',
#  '20210812',
#  '20210811',
#  '20210810',
#  '20210809',
#  '20210808',
#  '20210807',
#  '20210806',
#  '20210805',
#  '20210804',
#  '20210803',
#  '20210802',
#  '20210801',
#  '20210731',
#  '20210730',
#  '20210729',
#  '20210728',
#  '20210727',
#  '20210726',
#  '20210725',
#  '20210724',
#  '20210723',
#  '20210722',
#  '20210721',
#  '20210720',
#  '20210719',
#  '20210718',
#  '20210717',
#  '20210716',
#  '20210715',
#  '20210714',
#  '20210713',
#  '20210712',
#  '20210711',
#  '20210710',
#  '20210709',
#  '20210708',
#  '20210707',
#  '20210706',
#  '20210705',
#  '20210704',
#  '20210703',
#  '20210702',
#  '20210701',
#  '20210630',
#  '20210629',
#  '20210628',
#  '20210627',
#  '20210626',
# ...

# %%
# dataframe 생성
df_data = {
    '기준일': state_dt,
    '확진자수': decide_cnt,
    '사망자수': death_cnt,
    '치료중환자수': care_cnt
}
df_data
# Out:
# {'기준일': ['20210830',
#   '20210829',
#   '20210828',
#   '20210827',
#   '20210826',
#   '20210825',
#   '20210824',
#   '20210823',
#   '20210822',
#   '20210821',
#   '20210820',
#   '20210819',
#   '20210818',
#   '20210817',
#   '20210816',
#   '20210815',
#   '20210814',
#   '20210813',
#   '20210812',
#   '20210811',
#   '20210810',
#   '20210809',
#   '20210808',
#   '20210807',
#   '20210806',
#   '20210805',
#   '20210804',
#   '20210803',
#   '20210802',
#   '20210801',
#   '20210731',
#   '20210730',
#   '20210729',
#   '20210728',
#   '20210727',
#   '20210726',
#   '20210725',
#   '20210724',
#   '20210723',
#   '20210722',
#   '20210721',
#   '20210720',
#   '20210719',
#   '20210718',
#   '20210717',
#   '20210716',
#   '20210715',
#   '20210714',
#   '20210713',
#   '20210712',
#   '20210711',
#   '20210710',
#   '20210709',
#   '20210708',
#   '20210707',
#   '20210706',
#   '20210705',
#   '20210704',
#   '20210703',
#   '20210702',
#   '20210701',
#   '20210630',
# ...

# %%
df = pd.DataFrame(data=df_data)
df
# Out:
#           기준일    확진자수  사망자수 치료중환자수
# 0    20210830  250049  2284  27407
# 1    20210829  248561  2279  27556
# 2    20210828  246946  2276  27681
# 3    20210827  245153  2265  28215
# 4    20210826  243315  2257  28187
# ..        ...     ...   ...    ...
# 390  20200805   14456   302    770
# 391  20200804   14423   301    808
# 392  20200803   14389   301    806
# 393  20200802   14366   301    802
# 394  20200801   14336   301    821
#
# [395 rows x 4 columns]

# %% [markdown]
# ### 한국관광공사 - 관광정보서비스 (JSON)

# %%
ServiceKey = 'b9hGTJEotm7onQH20kHWpVbTbjOKOGAT8HYoLBOmXxGiN6uA2nrA8bpRss783vibuZoxkk51WJmsz83K3pVLkA%3D%3D'
PageNo = 1

url = 'http://api.visitkorea.or.kr/openapi/service/rest/KorService/areaCode?ServiceKey={}&numOfRows=10&pageNo={}&MobileOS=ETC&MobileApp=AppTest&_type=json'.format(serviceKey, pageNo)
url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fbb84c98e85d> in <module>
#       2 PageNo = 1
#       3
# ----> 4 url = 'http://api.visitkorea.or.kr/openapi/service/rest/KorService/areaCode?ServiceKey={}&numOfRows=10&pageNo={}&MobileOS=ETC&MobileApp=AppTest&_type=json'.format(serviceKey, pageNo)
#       5 url
#
# NameError: name 'pageNo' is not defined

# %%
res = requests.get(url)
res

# %%
res.text

# %%
data = res.json()
data

# %%
numOfRows = data['response']['body']['numOfRows']
totalCount = data['response']['body']['totalCount']

numOfRows, totalCount

# %%
queryCount = totalCount // numOfRows
queryCount

# %%
queryCount = totalCount // numOfRows
if totalCount % numOfRows > 0:
    queryCount += 1
queryCount

# %%
code = []
name = []
rnum = []

for i in range(queryCount):  # 0~1
    pageNo = i + 1  #  1~2
    url = url = 'http://api.visitkorea.or.kr/openapi/service/rest/KorService/areaCode?ServiceKey={}&numOfRows=10&pageNo={}&MobileOS=ETC&MobileApp=AppTest&_type=json'.format(serviceKey, pageNo)
    res = requests.get(url)
    data = res.json()
    items = data['response']['body']['items']['item']
    
    for item in items:
        code.append(item['code'])
        name.append(item['name'])
        rnum.append(item['rnum'])
        
name

# %%
df_data = {
    'code': code,
    'name': name,
    'rnum': rnum
}

df = pd.DataFrame(data=df_data)
df
